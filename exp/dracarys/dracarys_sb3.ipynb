# %%
import stable_baselines3
from stable_baselines3.common.env_checker import check_env
from dracarys.env import DracarysEnv

# %%
env = DracarysEnv()

# %%
check_env(env)

# %%
env.observation_space.shape, env.action_space
# Out:
# ((128, 128, 3), Discrete(8))

# %%
model = stable_baselines3.PPO (
    'CnnPolicy',
    env,
    verbose=1,
    tensorboard_log=r'F:\reward_lab\exp\dracarys\tensorboard_log',
    # exploration_final_eps=0.1,
    # exploration_fraction=0.3,
)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=400_000)
# Out:
# Logging to F:\reward_lab\exp\dracarys\tensorboard_log\PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 535      |
# |    ep_rew_mean     | 0        |
# | time/              |          |
# |    fps             | 29       |
# |    iterations      | 1        |
# |    time_elapsed    | 68       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 554         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 2           |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.024206389 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | -1.11       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0825     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0295     |
# |    value_loss           | 0.299       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 540         |
# |    ep_rew_mean          | 0           |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 3           |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.060040988 |
# |    clip_fraction        | 0.401       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | -0.73       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.134      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0805     |
# |    value_loss           | 0.00176     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 524        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 4          |
# |    time_elapsed         | 283        |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.09197708 |
# |    clip_fraction        | 0.541      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.01      |
# |    explained_variance   | -1.58      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.13      |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0986    |
# |    value_loss           | 0.00136    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 533        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 5          |
# |    time_elapsed         | 356        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.12691078 |
# |    clip_fraction        | 0.597      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.97      |
# |    explained_variance   | -1.88      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.149     |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.105     |
# |    value_loss           | 0.000907   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 534       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 28        |
# |    iterations           | 6         |
# |    time_elapsed         | 437       |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.1565761 |
# |    clip_fraction        | 0.652     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.93     |
# |    explained_variance   | -3.83     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.14     |
# |    n_updates            | 50        |
# |    policy_gradient_loss | -0.107    |
# |    value_loss           | 0.000685  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 545        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 7          |
# |    time_elapsed         | 509        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.16509303 |
# |    clip_fraction        | 0.667      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.93      |
# |    explained_variance   | -2.59      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.149     |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.116     |
# |    value_loss           | 0.000473   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 546        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 8          |
# |    time_elapsed         | 592        |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.19755885 |
# |    clip_fraction        | 0.694      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.85      |
# |    explained_variance   | -3.99      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.149     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.111     |
# |    value_loss           | 0.000335   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 552       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 27        |
# |    iterations           | 9         |
# |    time_elapsed         | 666       |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.1596117 |
# |    clip_fraction        | 0.608     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.89     |
# |    explained_variance   | -1.98     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.133    |
# |    n_updates            | 80        |
# |    policy_gradient_loss | -0.0981   |
# |    value_loss           | 0.000177  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 547        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 10         |
# |    time_elapsed         | 745        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.18004183 |
# |    clip_fraction        | 0.679      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.9       |
# |    explained_variance   | -1.67      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.137     |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.115     |
# |    value_loss           | 0.000117   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 547        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 11         |
# |    time_elapsed         | 824        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.20143381 |
# |    clip_fraction        | 0.703      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.89      |
# |    explained_variance   | -2.91      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.147     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.118     |
# |    value_loss           | 6.49e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 545        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 12         |
# |    time_elapsed         | 898        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.24799366 |
# |    clip_fraction        | 0.728      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.83      |
# |    explained_variance   | -2.66      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.146     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.121     |
# |    value_loss           | 3.54e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 547        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 13         |
# |    time_elapsed         | 962        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.20409779 |
# |    clip_fraction        | 0.719      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.85      |
# |    explained_variance   | -2.85      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.149     |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.116     |
# |    value_loss           | 2.38e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 552        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 14         |
# |    time_elapsed         | 1037       |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.22345299 |
# |    clip_fraction        | 0.716      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.81      |
# |    explained_variance   | -3.91      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.129     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.113     |
# |    value_loss           | 1.53e-05   |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 551      |
# |    ep_rew_mean          | 0        |
# | time/                   |          |
# |    fps                  | 27       |
# |    iterations           | 15       |
# |    time_elapsed         | 1105     |
# |    total_timesteps      | 30720    |
# | train/                  |          |
# |    approx_kl            | 0.241    |
# |    clip_fraction        | 0.746    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.78    |
# |    explained_variance   | -2.93    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.134   |
# |    n_updates            | 140      |
# |    policy_gradient_loss | -0.117   |
# |    value_loss           | 1.4e-05  |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 553        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 16         |
# |    time_elapsed         | 1178       |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.23616357 |
# |    clip_fraction        | 0.727      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.82      |
# |    explained_variance   | -2.61      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.151     |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.111     |
# |    value_loss           | 1.06e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 551        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 17         |
# |    time_elapsed         | 1249       |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.21862131 |
# |    clip_fraction        | 0.715      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.82      |
# |    explained_variance   | -2.52      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.137     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.111     |
# |    value_loss           | 1.1e-05    |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 547       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 27        |
# |    iterations           | 18        |
# |    time_elapsed         | 1322      |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.2119596 |
# |    clip_fraction        | 0.721     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.84     |
# |    explained_variance   | -4.59     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.16     |
# |    n_updates            | 170       |
# |    policy_gradient_loss | -0.108    |
# |    value_loss           | 1.25e-05  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 548        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 19         |
# |    time_elapsed         | 1389       |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.24599403 |
# |    clip_fraction        | 0.733      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.82      |
# |    explained_variance   | -5.8       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.136     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.121     |
# |    value_loss           | 6.75e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 548        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 20         |
# |    time_elapsed         | 1456       |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.26895297 |
# |    clip_fraction        | 0.744      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.78      |
# |    explained_variance   | -5.96      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.137     |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.117     |
# |    value_loss           | 6.58e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 547        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 21         |
# |    time_elapsed         | 1525       |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.22434902 |
# |    clip_fraction        | 0.738      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.84      |
# |    explained_variance   | -6.2       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.151     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.111     |
# |    value_loss           | 9.34e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 549        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 22         |
# |    time_elapsed         | 1598       |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.23923475 |
# |    clip_fraction        | 0.738      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.78      |
# |    explained_variance   | -8.42      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.153     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.111     |
# |    value_loss           | 9.82e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 547        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 23         |
# |    time_elapsed         | 1664       |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.25681978 |
# |    clip_fraction        | 0.754      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.75      |
# |    explained_variance   | -6.95      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.142     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.115     |
# |    value_loss           | 4.58e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 548        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 24         |
# |    time_elapsed         | 1736       |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.24678957 |
# |    clip_fraction        | 0.72       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.78      |
# |    explained_variance   | -9.28      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.148     |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.115     |
# |    value_loss           | 9.06e-06   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 551       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 28        |
# |    iterations           | 25        |
# |    time_elapsed         | 1808      |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.2985858 |
# |    clip_fraction        | 0.766     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.74     |
# |    explained_variance   | -8.04     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.149    |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -0.123    |
# |    value_loss           | 1.17e-05  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 552        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 26         |
# |    time_elapsed         | 1878       |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.22770628 |
# |    clip_fraction        | 0.755      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.75      |
# |    explained_variance   | -4.67      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.151     |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.123     |
# |    value_loss           | 2.54e-06   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 553       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 28        |
# |    iterations           | 27        |
# |    time_elapsed         | 1950      |
# |    total_timesteps      | 55296     |
# | train/                  |           |
# |    approx_kl            | 0.2778003 |
# |    clip_fraction        | 0.742     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.73     |
# |    explained_variance   | -4.87     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.145    |
# |    n_updates            | 260       |
# |    policy_gradient_loss | -0.116    |
# |    value_loss           | 1.02e-05  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 553        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 28         |
# |    time_elapsed         | 2021       |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.30740553 |
# |    clip_fraction        | 0.757      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.71      |
# |    explained_variance   | -6.6       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.15      |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.117     |
# |    value_loss           | 7.05e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 551        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 29         |
# |    time_elapsed         | 2095       |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.32363522 |
# |    clip_fraction        | 0.77       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.71      |
# |    explained_variance   | -8.48      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.156     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.124     |
# |    value_loss           | 4.45e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 552        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 30         |
# |    time_elapsed         | 2179       |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.27418983 |
# |    clip_fraction        | 0.747      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.75      |
# |    explained_variance   | -10.7      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.154     |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.118     |
# |    value_loss           | 1.69e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 551        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 28         |
# |    iterations           | 31         |
# |    time_elapsed         | 2258       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.35728693 |
# |    clip_fraction        | 0.768      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.63      |
# |    explained_variance   | -12.4      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0909    |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.109     |
# |    value_loss           | 2.31e-05   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 548       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 28        |
# |    iterations           | 32        |
# |    time_elapsed         | 2340      |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 0.3338705 |
# |    clip_fraction        | 0.77      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.7      |
# |    explained_variance   | -7.78     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.148    |
# |    n_updates            | 310       |
# |    policy_gradient_loss | -0.121    |
# |    value_loss           | 2.48e-06  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 551        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 33         |
# |    time_elapsed         | 2422       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.38992298 |
# |    clip_fraction        | 0.779      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.63      |
# |    explained_variance   | -7.13      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.152     |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.123     |
# |    value_loss           | 4.12e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 548        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 34         |
# |    time_elapsed         | 2498       |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.33314964 |
# |    clip_fraction        | 0.781      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.71      |
# |    explained_variance   | -6.9       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.151     |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.126     |
# |    value_loss           | 6.55e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 546        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 35         |
# |    time_elapsed         | 2593       |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.34035045 |
# |    clip_fraction        | 0.765      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.71      |
# |    explained_variance   | -9.33      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.159     |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.121     |
# |    value_loss           | 7.52e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 545        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 36         |
# |    time_elapsed         | 2690       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.33941647 |
# |    clip_fraction        | 0.773      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.72      |
# |    explained_variance   | -7.58      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.141     |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.12      |
# |    value_loss           | 3.23e-06   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 546       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 27        |
# |    iterations           | 37        |
# |    time_elapsed         | 2778      |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 0.3897208 |
# |    clip_fraction        | 0.789     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.63     |
# |    explained_variance   | -11.5     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.142    |
# |    n_updates            | 360       |
# |    policy_gradient_loss | -0.121    |
# |    value_loss           | 1.3e-05   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 547        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 38         |
# |    time_elapsed         | 2857       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.34666875 |
# |    clip_fraction        | 0.77       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.68      |
# |    explained_variance   | -9.01      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.132     |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.112     |
# |    value_loss           | 7.31e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 545        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 39         |
# |    time_elapsed         | 2933       |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.39623445 |
# |    clip_fraction        | 0.79       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.68      |
# |    explained_variance   | -11.9      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.151     |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.125     |
# |    value_loss           | 3.67e-06   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 541       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 27        |
# |    iterations           | 40        |
# |    time_elapsed         | 3017      |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 0.3459737 |
# |    clip_fraction        | 0.779     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.7      |
# |    explained_variance   | -7.32     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.16     |
# |    n_updates            | 390       |
# |    policy_gradient_loss | -0.126    |
# |    value_loss           | 2.3e-06   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 537        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 27         |
# |    iterations           | 41         |
# |    time_elapsed         | 3107       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.45723772 |
# |    clip_fraction        | 0.787      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.65      |
# |    explained_variance   | -11.6      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.163     |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.123     |
# |    value_loss           | 1.22e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 535        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 26         |
# |    iterations           | 42         |
# |    time_elapsed         | 3191       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.32964835 |
# |    clip_fraction        | 0.787      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.72      |
# |    explained_variance   | -11.5      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.131     |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.12      |
# |    value_loss           | 5.64e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 536        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 26         |
# |    iterations           | 43         |
# |    time_elapsed         | 3280       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.42150125 |
# |    clip_fraction        | 0.79       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.64      |
# |    explained_variance   | -4.73      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.146     |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.121     |
# |    value_loss           | 2.99e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 538        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 26         |
# |    iterations           | 44         |
# |    time_elapsed         | 3372       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.40807003 |
# |    clip_fraction        | 0.766      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.6       |
# |    explained_variance   | -4.95      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.143     |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.119     |
# |    value_loss           | 8.33e-06   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 536       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 26        |
# |    iterations           | 45        |
# |    time_elapsed         | 3458      |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.4410294 |
# |    clip_fraction        | 0.777     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.59     |
# |    explained_variance   | -7.6      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.15     |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.124    |
# |    value_loss           | 7.41e-06  |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 533      |
# |    ep_rew_mean          | 0        |
# | time/                   |          |
# |    fps                  | 26       |
# |    iterations           | 46       |
# |    time_elapsed         | 3551     |
# |    total_timesteps      | 94208    |
# | train/                  |          |
# |    approx_kl            | 0.347974 |
# |    clip_fraction        | 0.78     |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.61    |
# |    explained_variance   | -10.8    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.146   |
# |    n_updates            | 450      |
# |    policy_gradient_loss | -0.122   |
# |    value_loss           | 9.17e-06 |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 535        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 26         |
# |    iterations           | 47         |
# |    time_elapsed         | 3640       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.41296726 |
# |    clip_fraction        | 0.771      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.62      |
# |    explained_variance   | -7.68      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.14      |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.118     |
# |    value_loss           | 1.14e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 531        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 26         |
# |    iterations           | 48         |
# |    time_elapsed         | 3734       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.48835328 |
# |    clip_fraction        | 0.791      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.54      |
# |    explained_variance   | -8.33      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.143     |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.122     |
# |    value_loss           | 1.11e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 529        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 26         |
# |    iterations           | 49         |
# |    time_elapsed         | 3841       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.45438892 |
# |    clip_fraction        | 0.773      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.59      |
# |    explained_variance   | -14.6      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.15      |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.124     |
# |    value_loss           | 1.63e-05   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 528       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 25        |
# |    iterations           | 50        |
# |    time_elapsed         | 3948      |
# |    total_timesteps      | 102400    |
# | train/                  |           |
# |    approx_kl            | 0.5373628 |
# |    clip_fraction        | 0.797     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.57     |
# |    explained_variance   | -12.7     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.158    |
# |    n_updates            | 490       |
# |    policy_gradient_loss | -0.122    |
# |    value_loss           | 1.26e-05  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 525        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 25         |
# |    iterations           | 51         |
# |    time_elapsed         | 4048       |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.35811502 |
# |    clip_fraction        | 0.744      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.6       |
# |    explained_variance   | -6.28      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.142     |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.114     |
# |    value_loss           | 9.41e-06   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 526       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 25        |
# |    iterations           | 52        |
# |    time_elapsed         | 4134      |
# |    total_timesteps      | 106496    |
# | train/                  |           |
# |    approx_kl            | 0.5070013 |
# |    clip_fraction        | 0.79      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.55     |
# |    explained_variance   | -6.94     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.147    |
# |    n_updates            | 510       |
# |    policy_gradient_loss | -0.119    |
# |    value_loss           | 3.26e-05  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 521       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 25        |
# |    iterations           | 53        |
# |    time_elapsed         | 4223      |
# |    total_timesteps      | 108544    |
# | train/                  |           |
# |    approx_kl            | 0.3789978 |
# |    clip_fraction        | 0.716     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.52     |
# |    explained_variance   | -10.7     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.111    |
# |    n_updates            | 520       |
# |    policy_gradient_loss | -0.105    |
# |    value_loss           | 2.82e-05  |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 523      |
# |    ep_rew_mean          | 0        |
# | time/                   |          |
# |    fps                  | 25       |
# |    iterations           | 54       |
# |    time_elapsed         | 4310     |
# |    total_timesteps      | 110592   |
# | train/                  |          |
# |    approx_kl            | 0.518588 |
# |    clip_fraction        | 0.777    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.48    |
# |    explained_variance   | -12.1    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.138   |
# |    n_updates            | 530      |
# |    policy_gradient_loss | -0.122   |
# |    value_loss           | 2.79e-06 |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 524        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 25         |
# |    iterations           | 55         |
# |    time_elapsed         | 4392       |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.45009795 |
# |    clip_fraction        | 0.759      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.49      |
# |    explained_variance   | -4.88      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.126     |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.111     |
# |    value_loss           | 1.05e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 524        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 25         |
# |    iterations           | 56         |
# |    time_elapsed         | 4474       |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.54081273 |
# |    clip_fraction        | 0.769      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.58      |
# |    explained_variance   | -7.88      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.146     |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.115     |
# |    value_loss           | 4.1e-06    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 524        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 25         |
# |    iterations           | 57         |
# |    time_elapsed         | 4564       |
# |    total_timesteps      | 116736     |
# | train/                  |            |
# |    approx_kl            | 0.46634278 |
# |    clip_fraction        | 0.774      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.53      |
# ...
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.63      |
# |    explained_variance   | -12.1      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.132     |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.122     |
# |    value_loss           | 4.77e-07   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 524        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 25         |
# |    iterations           | 59         |
# |    time_elapsed         | 4799       |
# |    total_timesteps      | 120832     |
# | train/                  |            |
# |    approx_kl            | 0.50563943 |
# |    clip_fraction        | 0.79       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.57      |
# |    explained_variance   | -12.5      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.139     |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.124     |
# |    value_loss           | 1.34e-05   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 527       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 25        |
# |    iterations           | 60        |
# |    time_elapsed         | 4885      |
# |    total_timesteps      | 122880    |
# | train/                  |           |
# |    approx_kl            | 0.5608978 |
# |    clip_fraction        | 0.782     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.55     |
# |    explained_variance   | -15.2     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.134    |
# |    n_updates            | 590       |
# |    policy_gradient_loss | -0.119    |
# |    value_loss           | 2.17e-05  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 529        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 25         |
# |    iterations           | 61         |
# |    time_elapsed         | 4976       |
# |    total_timesteps      | 124928     |
# | train/                  |            |
# |    approx_kl            | 0.47556743 |
# |    clip_fraction        | 0.776      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.54      |
# |    explained_variance   | -10.2      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.149     |
# |    n_updates            | 600        |
# |    policy_gradient_loss | -0.117     |
# |    value_loss           | 6.26e-06   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 529       |
# |    ep_rew_mean          | 0         |
# | time/                   |           |
# |    fps                  | 25        |
# |    iterations           | 62        |
# |    time_elapsed         | 5077      |
# |    total_timesteps      | 126976    |
# | train/                  |           |
# |    approx_kl            | 0.4794764 |
# |    clip_fraction        | 0.766     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.56     |
# |    explained_variance   | -10.4     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.141    |
# |    n_updates            | 610       |
# |    policy_gradient_loss | -0.108    |
# |    value_loss           | 1.78e-05  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 529        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 25         |
# |    iterations           | 63         |
# |    time_elapsed         | 5160       |
# |    total_timesteps      | 129024     |
# | train/                  |            |
# |    approx_kl            | 0.46111375 |
# |    clip_fraction        | 0.767      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.54      |
# |    explained_variance   | -8.38      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.134     |
# |    n_updates            | 620        |
# |    policy_gradient_loss | -0.112     |
# |    value_loss           | 4.16e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 531        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 24         |
# |    iterations           | 64         |
# |    time_elapsed         | 5245       |
# |    total_timesteps      | 131072     |
# | train/                  |            |
# |    approx_kl            | 0.41465792 |
# |    clip_fraction        | 0.782      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.64      |
# |    explained_variance   | -7.28      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.152     |
# |    n_updates            | 630        |
# |    policy_gradient_loss | -0.122     |
# |    value_loss           | 6.49e-07   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 533        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 24         |
# |    iterations           | 65         |
# |    time_elapsed         | 5328       |
# |    total_timesteps      | 133120     |
# | train/                  |            |
# |    approx_kl            | 0.45542645 |
# |    clip_fraction        | 0.775      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.62      |
# |    explained_variance   | -5.59      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.135     |
# |    n_updates            | 640        |
# |    policy_gradient_loss | -0.114     |
# |    value_loss           | 1.01e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 536        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 24         |
# |    iterations           | 66         |
# |    time_elapsed         | 5415       |
# |    total_timesteps      | 135168     |
# | train/                  |            |
# |    approx_kl            | 0.48555452 |
# |    clip_fraction        | 0.777      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.62      |
# |    explained_variance   | -13.5      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.122     |
# |    n_updates            | 650        |
# |    policy_gradient_loss | -0.108     |
# |    value_loss           | 3.64e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 538        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 24         |
# |    iterations           | 67         |
# |    time_elapsed         | 5526       |
# |    total_timesteps      | 137216     |
# | train/                  |            |
# |    approx_kl            | 0.35898528 |
# |    clip_fraction        | 0.731      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.66      |
# |    explained_variance   | -9.59      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.143     |
# |    n_updates            | 660        |
# |    policy_gradient_loss | -0.109     |
# |    value_loss           | 1.91e-05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 538        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 24         |
# |    iterations           | 68         |
# |    time_elapsed         | 5699       |
# |    total_timesteps      | 139264     |
# | train/                  |            |
# |    approx_kl            | 0.49032426 |
# |    clip_fraction        | 0.779      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.56      |
# |    explained_variance   | -6.55      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.146     |
# |    n_updates            | 670        |
# |    policy_gradient_loss | -0.117     |
# |    value_loss           | 5.35e-06   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 536        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 24         |
# |    iterations           | 69         |
# |    time_elapsed         | 5802       |
# |    total_timesteps      | 141312     |
# | train/                  |            |
# |    approx_kl            | 0.36195475 |
# |    clip_fraction        | 0.773      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.68      |
# |    explained_variance   | -3.45      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.125     |
# |    n_updates            | 680        |
# |    policy_gradient_loss | -0.12      |
# |    value_loss           | 9.05e-07   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 537        |
# |    ep_rew_mean          | 0          |
# | time/                   |            |
# |    fps                  | 24         |
# |    iterations           | 70         |
# |    time_elapsed         | 5906       |
# |    total_timesteps      | 143360     |
# | train/                  |            |
# |    approx_kl            | 0.42500758 |
# |    clip_fraction        | 0.786      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.63      |
# |    explained_variance   | -3.91      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.15      |
# |    n_updates            | 690        |
# |    policy_gradient_loss | -0.121     |
# |    value_loss           | 8.23e-07   |
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 model.learn(total_timesteps=400_000)
#
# File ~\miniconda3\envs\reward_lab\lib\site-packages\stable_baselines3\ppo\ppo.py:317, in PPO.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     303 def learn(
#     304     self: PPOSelf,
#     305     total_timesteps: int,
#    (...)
#     314     progress_bar: bool = False,
#     315 ) -> PPOSelf:
# --> 317     return super().learn(
#     318         total_timesteps=total_timesteps,
#     319         callback=callback,
#     320         log_interval=log_interval,
#     321         eval_env=eval_env,
#     322         eval_freq=eval_freq,
#     323         n_eval_episodes=n_eval_episodes,
#     324         tb_log_name=tb_log_name,
#     325         eval_log_path=eval_log_path,
#     326         reset_num_timesteps=reset_num_timesteps,
#     327         progress_bar=progress_bar,
#     328     )
#
# File ~\miniconda3\envs\reward_lab\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:262, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     258 callback.on_training_start(locals(), globals())
#     260 while self.num_timesteps < total_timesteps:
# --> 262     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     264     if continue_training is False:
#     265         break
#
# File ~\miniconda3\envs\reward_lab\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:181, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     178 if isinstance(self.action_space, gym.spaces.Box):
#     179     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 181 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     183 self.num_timesteps += env.num_envs
#     185 # Give access to local variables
#
# File ~\miniconda3\envs\reward_lab\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:162, in VecEnv.step(self, actions)
#     155 """
#     156 Step the environments with the given action
#     157
#     158 :param actions: the action
#     159 :return: observation, reward, done, information
#     160 """
#     161 self.step_async(actions)
# --> 162 return self.step_wait()
#
# File ~\miniconda3\envs\reward_lab\lib\site-packages\stable_baselines3\common\vec_env\vec_transpose.py:95, in VecTransposeImage.step_wait(self)
#      94 def step_wait(self) -> VecEnvStepReturn:
# ---> 95     observations, rewards, dones, infos = self.venv.step_wait()
#      97     # Transpose the terminal observations
#      98     for idx, done in enumerate(dones):
#
# File ~\miniconda3\envs\reward_lab\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:43, in DummyVecEnv.step_wait(self)
#      41 def step_wait(self) -> VecEnvStepReturn:
#      42     for env_idx in range(self.num_envs):
# ---> 43         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      44             self.actions[env_idx]
#      45         )
#      46         if self.buf_dones[env_idx]:
#      47             # save final observation where user can get it, then reset
#      48             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File ~\miniconda3\envs\reward_lab\lib\site-packages\stable_baselines3\common\monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, done, info = self.env.step(action)
#      95 self.rewards.append(reward)
#      96 if done:
#
# File F:\gyms\dracarys\dracarys\env.py:68, in DracarysEnv.step(self, action)
#      66 self.player.policy = lambda **_: discrete_actions_to_continuos(action)
#      67 for i in range(self.game.params.episode.frames_per_timestep):
# ---> 68     self.game.step()
#      69 done = self.game.episode_manager.ended
#      70 observation = self.render()
#
# File F:\gyms\dracarys\dracarys\game.py:21, in Game.step(self)
#      19 def step(self):
#      20     self.episode_manager.step()
# ---> 21     self.objects_manager.step()
#      22     self.world.step()
#      23     self.stats.step()
#
# File F:\gyms\dracarys\dracarys\objects_manager.py:33, in ObjectsManager.step(self)
#      31 def step(self):
#      32     for character in self.objects():
# ---> 33         character.step()
#      35     # Clean up any dead characters
#      36     self.animals = self._clean_up_dead(self.animals)
#
# File F:\gyms\dracarys\dracarys\objects\crossbow.py:64, in CrossBow.step(self)
#      62 min_dragon = None
#      63 for dragon in self.game.objects_manager.dragons:
# ---> 64     distance = get_distance(dragon.body.position, self.center)
#      65     if distance < self.p.observable_distance and distance < min_distance:
#      66         min_distance = distance
#
# File ~\miniconda3\envs\reward_lab\lib\site-packages\pymunk\body.py:312, in Body._get_position(self)
#     311 def _get_position(self) -> Vec2d:
# --> 312     v = lib.cpBodyGetPosition(self._body)
#     313     return Vec2d(v.x, v.y)
#
# KeyboardInterrupt:
