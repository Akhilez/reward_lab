# %%
from exp.mujoco_exp.swimmer.swimmer import swimmer6

# %%
env = swimmer6()
env.reset()
env.action_spec(), env.observation_spec(), env.reward_spec()
# Out:
# (BoundedArray(shape=(5,), dtype=dtype('float64'), name=None, minimum=[-1. -1. -1. -1. -1.], maximum=[1. 1. 1. 1. 1.]),
#  {'joints': Array(shape=(5,), dtype=dtype('float64'), name='joints'),
#   'to_target': Array(shape=(2,), dtype=dtype('float64'), name='to_target'),
#   'body_velocities': Array(shape=(18,), dtype=dtype('float64'), name='body_velocities')},
#  Array(shape=(), dtype=dtype('float64'), name='reward'))

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=320x240>
